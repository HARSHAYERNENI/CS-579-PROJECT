# %%
import tensorflow_datasets as tfds
import tensorflow as tf

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=False)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Print some basic information about the dataset
print(info)

# Function to preprocess the images and segmentation masks
def preprocess(features):
    image = tf.image.resize(features['image'], (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)

    segmentation_mask = tf.image.resize(features['segmentation_mask'], (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32)
    segmentation_mask = segmentation_mask / 255.0  # Normalize to [0, 1]
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)  # Binarize

    return image, segmentation_mask

# Apply the preprocess function to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Example: Access an image and segmentation mask
for image, segmentation_mask in train_data.take(1):
    print(f"Image shape: {image.shape}")
    print(f"Segmentation mask shape: {segmentation_mask.shape}")
# Out:
# tfds.core.DatasetInfo(
#     name='oxford_iiit_pet',
#     full_name='oxford_iiit_pet/4.0.0',
#     description="""
#     The Oxford-IIIT pet dataset is a 37 category pet image dataset with roughly 200
#     images for each class. The images have large variations in scale, pose and
#     lighting. All images have an associated ground truth annotation of breed and
#     species. Additionally, head bounding boxes are provided for the training split,
#     allowing using this dataset for simple object detection tasks. In the test
#     split, the bounding boxes are empty.
#     """,
#     homepage='http://www.robots.ox.ac.uk/~vgg/data/pets/',
#     data_dir='C:\\Users\\harsh\\tensorflow_datasets\\oxford_iiit_pet\\4.0.0',
#     file_format=tfrecord,
#     download_size=Unknown size,
#     dataset_size=773.68 MiB,
#     features=FeaturesDict({
#         'file_name': Text(shape=(), dtype=string),
#         'head_bbox': BBoxFeature(shape=(4,), dtype=float32),
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=False)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Print some basic information about the dataset
print(info)

# Function to preprocess the images, segmentation masks, and binary labels
def preprocess(features):
    image = tf.image.resize(features['image'], (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)

    # Focus only on foreground (pets) and background
    segmentation_mask = tf.image.resize(features['segmentation_mask'], (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32)
    segmentation_mask = segmentation_mask / 255.0  # Normalize to [0, 1]
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)  # Binarize

    # Convert breed labels into binary labels: 0 for cat, 1 for dog
    binary_label = tf.where(features['label'] < 25, 0, 1)  # Assuming the first 25 labels are cats and the rest are dogs

    return image, binary_label, segmentation_mask

# Apply the preprocess function to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Example: Access an image, binary label, and segmentation mask
for image, binary_label, segmentation_mask in train_data.take(1):
    print(f"Image shape: {image.shape}")
    print(f"Binary label: {binary_label}")
    print(f"Segmentation mask shape: {segmentation_mask.shape}")
# Out:
# tfds.core.DatasetInfo(
#     name='oxford_iiit_pet',
#     full_name='oxford_iiit_pet/4.0.0',
#     description="""
#     The Oxford-IIIT pet dataset is a 37 category pet image dataset with roughly 200
#     images for each class. The images have large variations in scale, pose and
#     lighting. All images have an associated ground truth annotation of breed and
#     species. Additionally, head bounding boxes are provided for the training split,
#     allowing using this dataset for simple object detection tasks. In the test
#     split, the bounding boxes are empty.
#     """,
#     homepage='http://www.robots.ox.ac.uk/~vgg/data/pets/',
#     data_dir='C:\\Users\\harsh\\tensorflow_datasets\\oxford_iiit_pet\\4.0.0',
#     file_format=tfrecord,
#     download_size=Unknown size,
#     dataset_size=773.68 MiB,
#     features=FeaturesDict({
#         'file_name': Text(shape=(), dtype=string),
#         'head_bbox': BBoxFeature(shape=(4,), dtype=float32),
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=False)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Preprocess the images and segmentation masks
def preprocess(features):
    image = tf.image.resize(features['image'], (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)

    segmentation_mask = tf.image.resize(features['segmentation_mask'], (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32) / 255.0
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)

    return image, segmentation_mask

# Apply preprocessing to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Simple CNN model for semantic segmentation
def create_simple_cnn(input_shape):
    model = models.Sequential([
        layers.InputLayer(input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(1, (1, 1), activation='sigmoid', padding='same')
    ])
    return model

# Create the model
model = create_simple_cnn((128, 128, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.9540 - loss: 1.2486 - val_accuracy: 1.0000 - val_loss: 1.0420e-05
# Epoch 2/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 1.0000 - loss: 9.2200e-06 - val_accuracy: 1.0000 - val_loss: 1.4246e-06
# Epoch 3/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 1.0000 - loss: 1.6137e-06 - val_accuracy: 1.0000 - val_loss: 5.8795e-07
# Epoch 4/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 1.0000 - loss: 7.0103e-07 - val_accuracy: 1.0000 - val_loss: 3.2321e-07
# Epoch 5/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 1.0000 - loss: 3.9573e-07 - val_accuracy: 1.0000 - val_loss: 2.0615e-07
# Epoch 6/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 1.0000 - loss: 2.5652e-07 - val_accuracy: 1.0000 - val_loss: 1.4392e-07
# Epoch 7/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 1.0000 - loss: 1.8101e-07 - val_accuracy: 1.0000 - val_loss: 1.0664e-07
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

# Visualize some inference results
def visualize_predictions(model, dataset, num_images=5):
    for image, segmentation_mask in dataset.take(num_images):
        image_resized = tf.image.resize(image, (128, 128))
        image_resized = tf.expand_dims(image_resized, axis=0)  # Add batch dimension
        image_resized = tf.image.convert_image_dtype(image_resized, tf.float32)

        pred_mask = model.predict(image_resized)
        pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
        pred_mask = tf.where(pred_mask > 0.5, 1, 0)

        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(image.numpy())
        plt.title("Image")
        
        plt.subplot(1, 3, 2)
        plt.imshow(segmentation_mask.numpy().squeeze(), cmap='gray')
        plt.title("True Mask")
        
        plt.subplot(1, 3, 3)
        plt.imshow(pred_mask.numpy().squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        
        plt.show()

# Visualize results on the test data
visualize_predictions(model, test_data, num_images=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 30
#      27         plt.show()
#      29 # Visualize results on the test data
# ---> 30 visualize_predictions(model, test_data, num_images=3)
#
# Cell In[17], line 10, in visualize_predictions(model, dataset, num_images)
#       7 image_resized = tf.expand_dims(image_resized, axis=0)  # Add batch dimension
#       8 image_resized = tf.image.convert_image_dtype(image_resized, tf.float32)
# ---> 10 pred_mask = model.predict(image_resized)
#      11 pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
#      12 pred_mask = tf.where(pred_mask > 0.5, 1, 0)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=True)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Preprocess the images and segmentation masks
def preprocess(image, segmentation_mask):
    image = tf.image.resize(image, (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)

    segmentation_mask = tf.image.resize(segmentation_mask, (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32) / 255.0
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)

    return image, segmentation_mask

# Apply preprocessing to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Simple CNN model for semantic segmentation
def create_simple_cnn(input_shape):
    model = models.Sequential([
        layers.InputLayer(input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(1, (1, 1), activation='sigmoid', padding='same')
    ])
    return model

# Create the model
model = create_simple_cnn((128, 128, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 25
#      22     return image, segmentation_mask
#      24 # Apply preprocessing to the datasets
# ---> 25 train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      26 val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      27 test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\data\ops\dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=True)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Preprocess the images and segmentation masks
def preprocess(image, segmentation_mask):
    image = tf.image.resize(image, (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)

    segmentation_mask = tf.expand_dims(segmentation_mask, axis=-1)  # Ensure the mask has a channel dimension
    segmentation_mask = tf.image.resize(segmentation_mask, (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32) / 255.0
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)

    return image, segmentation_mask

# Apply preprocessing to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Simple CNN model for semantic segmentation
def create_simple_cnn(input_shape):
    model = models.Sequential([
        layers.InputLayer(input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(1, (1, 1), activation='sigmoid', padding='same')
    ])
    return model

# Create the model
model = create_simple_cnn((128, 128, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# Visualize some inference results
def visualize_predictions(model, dataset, num_images=5):
    for image, segmentation_mask in dataset.take(num_images):
        image_resized = tf.image.resize(image, (128, 128))
        image_resized = tf.expand_dims(image_resized, axis=0)  # Add batch dimension

        pred_mask = model.predict(image_resized)
        pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
        pred_mask = tf.where(pred_mask > 0.5, 1, 0)

        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(image.numpy())
        plt.title("Image")
        
        plt.subplot(1, 3, 2)
        plt.imshow(segmentation_mask.numpy().squeeze(), cmap='gray')
        plt.title("True Mask")
        
        plt.subplot(1, 3, 3)
        plt.imshow(pred_mask.numpy().squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        
        plt.show()

# Visualize results on the test data
visualize_predictions(model, test_data, num_images=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 26
#      23     return image, segmentation_mask
#      25 # Apply preprocessing to the datasets
# ---> 26 train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      27 val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      28 test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\data\ops\dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=True)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Print some basic information about the dataset
print(info)

# Preprocess the images and segmentation masks
def preprocess(image, segmentation_mask):
    image = tf.image.resize(image, (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)

    # Ensure the segmentation mask has the correct dimensions
    segmentation_mask = tf.expand_dims(segmentation_mask, axis=-1)  # Add channel dimension if missing
    print(f"Segmentation mask shape before resizing: {segmentation_mask.shape}")  # Debug print
    
    segmentation_mask = tf.image.resize(segmentation_mask, (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32) / 255.0
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)
    print(f"Segmentation mask shape after resizing: {segmentation_mask.shape}")  # Debug print

    return image, segmentation_mask

# Apply preprocessing to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Simple CNN model for semantic segmentation
def create_simple_cnn(input_shape):
    model = models.Sequential([
        layers.InputLayer(input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(1, (1, 1), activation='sigmoid', padding='same')
    ])
    return model

# Create the model
model = create_simple_cnn((128, 128, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# Visualize some inference results
def visualize_predictions(model, dataset, num_images=5):
    for image, segmentation_mask in dataset.take(num_images):
        image_resized = tf.image.resize(image, (128, 128))
        image_resized = tf.expand_dims(image_resized, axis=0)  # Add batch dimension

        pred_mask = model.predict(image_resized)
        pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
        pred_mask = tf.where(pred_mask > 0.5, 1, 0)

        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(image.numpy())
        plt.title("Image")
        
        plt.subplot(1, 3, 2)
        plt.imshow(segmentation_mask.numpy().squeeze(), cmap='gray')
        plt.title("True Mask")
        
        plt.subplot(1, 3, 3)
        plt.imshow(pred_mask.numpy().squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        
        plt.show()

# Visualize results on the test data
visualize_predictions(model, test_data, num_images=3)
# Out:
# tfds.core.DatasetInfo(
#     name='oxford_iiit_pet',
#     full_name='oxford_iiit_pet/4.0.0',
#     description="""
#     The Oxford-IIIT pet dataset is a 37 category pet image dataset with roughly 200
#     images for each class. The images have large variations in scale, pose and
#     lighting. All images have an associated ground truth annotation of breed and
#     species. Additionally, head bounding boxes are provided for the training split,
#     allowing using this dataset for simple object detection tasks. In the test
#     split, the bounding boxes are empty.
#     """,
#     homepage='http://www.robots.ox.ac.uk/~vgg/data/pets/',
#     data_dir='C:\\Users\\harsh\\tensorflow_datasets\\oxford_iiit_pet\\4.0.0',
#     file_format=tfrecord,
#     download_size=Unknown size,
#     dataset_size=773.68 MiB,
#     features=FeaturesDict({
#         'file_name': Text(shape=(), dtype=string),
#         'head_bbox': BBoxFeature(shape=(4,), dtype=float32),
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=True)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Preprocess images and segmentation masks
def preprocess(image, segmentation_mask):
    image = tf.image.resize(image, (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)
    
    segmentation_mask = tf.expand_dims(segmentation_mask, axis=-1)  # Ensure the mask has a channel dimension
    segmentation_mask = tf.image.resize(segmentation_mask, (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32) / 255.0
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)

    return image, segmentation_mask

# Apply preprocessing to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Simple CNN model for semantic segmentation
def create_simple_cnn(input_shape):
    model = models.Sequential([
        layers.InputLayer(input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(1, (1, 1), activation='sigmoid', padding='same')
    ])
    return model

# Create the model
model = create_simple_cnn((128, 128, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# Visualize some inference results
def visualize_predictions(model, dataset, num_images=5):
    for image, segmentation_mask in dataset.take(num_images):
        image_resized = tf.image.resize(image, (128, 128))
        image_resized = tf.expand_dims(image_resized, axis=0)  # Add batch dimension

        pred_mask = model.predict(image_resized)
        pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
        pred_mask = tf.where(pred_mask > 0.5, 1, 0)

        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(image.numpy())
        plt.title("Image")
        
        plt.subplot(1, 3, 2)
        plt.imshow(segmentation_mask.numpy().squeeze(), cmap='gray')
        plt.title("True Mask")
        
        plt.subplot(1, 3, 3)
        plt.imshow(pred_mask.numpy().squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        
        plt.show()

# Visualize results on the test data
visualize_predictions(model, test_data, num_images=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 26
#      23     return image, segmentation_mask
#      25 # Apply preprocessing to the datasets
# ---> 26 train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      27 val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      28 test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\data\ops\dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=True)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Preprocess images and segmentation masks
def preprocess(image, segmentation_mask):
    image = tf.image.resize(image, (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)

    segmentation_mask = tf.expand_dims(segmentation_mask, axis=-1)  # Ensure the mask has a channel dimension
    segmentation_mask = tf.image.resize(segmentation_mask, (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32) / 255.0
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)

    return image, segmentation_mask

# Apply preprocessing to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Simple CNN model for semantic segmentation
def create_simple_cnn(input_shape):
    model = models.Sequential([
        layers.InputLayer(input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(1, (1, 1), activation='sigmoid', padding='same')
    ])
    return model

# Create the model
model = create_simple_cnn((128, 128, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# Visualize some inference results
def visualize_predictions(model, dataset, num_images=5):
    for image, segmentation_mask in dataset.take(num_images):
        image_resized = tf.image.resize(image, (128, 128))
        image_resized = tf.expand_dims(image_resized, axis=0)  # Add batch dimension

        pred_mask = model.predict(image_resized)
        pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
        pred_mask = tf.where(pred_mask > 0.5, 1, 0)

        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(image.numpy())
        plt.title("Image")
        
        plt.subplot(1, 3, 2)
        plt.imshow(segmentation_mask.numpy().squeeze(), cmap='gray')
        plt.title("True Mask")
        
        plt.subplot(1, 3, 3)
        plt.imshow(pred_mask.numpy().squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        
        plt.show()

# Visualize results on the test data
visualize_predictions(model, test_data, num_images=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 26
#      23     return image, segmentation_mask
#      25 # Apply preprocessing to the datasets
# ---> 26 train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      27 val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      28 test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\data\ops\dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=True)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Preprocess images and segmentation masks
def preprocess(image, segmentation_mask):
    image = tf.image.resize(image, (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)
    
    segmentation_mask = tf.expand_dims(segmentation_mask, axis=-1)  # Ensure the mask has a channel dimension
    segmentation_mask = tf.image.resize(segmentation_mask, (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32) / 255.0
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)

    return image, segmentation_mask

# Apply preprocessing to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Simple CNN model for semantic segmentation
def create_simple_cnn(input_shape):
    model = models.Sequential([
        layers.InputLayer(input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(1, (1, 1), activation='sigmoid', padding='same')
    ])
    return model

# Create the model
model = create_simple_cnn((128, 128, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# Visualize some inference results
def visualize_predictions(model, dataset, num_images=5):
    for image, segmentation_mask in dataset.take(num_images):
        image_resized = tf.image.resize(image, (128, 128))
        image_resized = tf.expand_dims(image_resized, axis=0)  # Add batch dimension

        pred_mask = model.predict(image_resized)
        pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
        pred_mask = tf.where(pred_mask > 0.5, 1, 0)

        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(image.numpy())
        plt.title("Image")
        
        plt.subplot(1, 3, 2)
        plt.imshow(segmentation_mask.numpy().squeeze(), cmap='gray')
        plt.title("True Mask")
        
        plt.subplot(1, 3, 3)
        plt.imshow(pred_mask.numpy().squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        
        plt.show()

# Visualize results on the test data
visualize_predictions(model, test_data, num_images=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 26
#      23     return image, segmentation_mask
#      25 # Apply preprocessing to the datasets
# ---> 26 train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      27 val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#      28 test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\data\ops\dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=False)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Preprocess images and segmentation masks
def preprocess(features):
    image = features['image']
    segmentation_mask = features['segmentation_mask']

    image = tf.image.resize(image, (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)
    
    segmentation_mask = tf.image.resize(tf.expand_dims(segmentation_mask, axis=-1), (128, 128))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32) / 255.0
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)

    return image, segmentation_mask

# Apply preprocessing to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Simple CNN model for semantic segmentation
def create_simple_cnn(input_shape):
    model = models.Sequential([
        layers.InputLayer(input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(1, (1, 1), activation='sigmoid', padding='same')
    ])
    return model

# Create the model
model = create_simple_cnn((128, 128, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# Visualize some inference results
def visualize_predictions(model, dataset, num_images=5):
    for features in dataset.take(num_images):
        image = features['image']
        segmentation_mask = features['segmentation_mask']
        
        image_resized = tf.image.resize(image, (128, 128))
        image_resized = tf.expand_dims(image_resized, axis=0)  # Add batch dimension

        pred_mask = model.predict(image_resized)
        pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
        pred_mask = tf.where(pred_mask > 0.5, 1, 0)

        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(image.numpy())
        plt.title("Image")
        
        plt.subplot(1, 3, 2)
        plt.imshow(segmentation_mask.numpy().squeeze(), cmap='gray')
        plt.title("True Mask")
        
        plt.subplot(1, 3, 3)
        plt.imshow(pred_mask.numpy().squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        
        plt.show()

# Visualize results on the test data
visualize_predictions(model, test_data, num_images=3)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 53
#      50 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      52 # Train the model
# ---> 53 history = model.fit(train_data, epochs=10, validation_data=val_data)
#      55 # Plot the training and validation loss
#      56 plt.plot(history.history['loss'], label='Train Loss')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Load the Oxford Pet Dataset
dataset, info = tfds.load('oxford_iiit_pet', with_info=True, as_supervised=True)

# Split into training and testing datasets
train_dataset = dataset['train']
test_dataset = dataset['test']

# Preprocess images and segmentation masks
def preprocess(image, segmentation_mask):
    image = tf.image.resize(image, (128, 128))
    image = tf.image.convert_image_dtype(image, tf.float32)
    
    segmentation_mask = tf.expand_dims(segmentation_mask, axis=-1)  # Ensure the mask has a channel dimension
    segmentation_mask = tf.image.resize(segmentation_mask, (128, 128, 1))
    segmentation_mask = tf.cast(segmentation_mask, tf.float32) / 255.0
    segmentation_mask = tf.where(segmentation_mask > 0.5, 1, 0)

    return image, segmentation_mask

# Apply preprocessing to the datasets
train_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
val_data = train_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)
test_data = test_dataset.map(preprocess).batch(32).prefetch(tf.data.AUTOTUNE)

# Simple CNN model for semantic segmentation
def create_simple_cnn(input_shape):
    model = models.Sequential([
        layers.InputLayer(input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(1, (1, 1), activation='sigmoid', padding='same')
    ])
    return model

# Create the model
model = create_simple_cnn((128, 128, 3))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, epochs=10, validation_data=val_data)

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

# Visualize some inference results
def visualize_predictions(model, dataset, num_images=5):
    for image, segmentation_mask in dataset.take(num_images):
        image_resized = tf.image.resize(image, (128, 128))
        image_resized = tf.expand_dims(image_resized, axis=0)  # Add batch dimension

        pred_mask = model.predict(image_resized)
        pred_mask = tf.squeeze(pred_mask, axis=0)  # Remove batch dimension
        pred_mask = tf.where(pred_mask > 0.5, 1, 0)

        plt.figure(figsize=(12, 6))
        plt.subplot(1, 3, 1)
        plt.imshow(image.numpy())
        plt.title("Image")
        
        plt.subplot(1, 3, 2)
        plt.imshow(segmentation_mask.numpy().squeeze(), cmap='gray')
        plt.title("True Mask")
        
        plt.subplot(1, 3, 3)
        plt.imshow(pred_mask.numpy().squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        
        plt.show()

# Visualize results on the test data
visualize_predictions(model, test_data, num_images=3)
